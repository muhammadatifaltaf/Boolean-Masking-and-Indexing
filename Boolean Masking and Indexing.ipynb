# %% [markdown]
# # Boolean Mask

# %%
import pandas as pd

# %%
df = pd.read_csv('Iris.csv', index_col=0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
admit_mask=df['sepalwidthcm'] > 3.1
admit_mask
# Out:
# Id
# 1       True
# 2      False
# 3       True
# 4      False
# 5       True
#        ...
# 146    False
# 147    False
# 148    False
# 149     True
# 150    False
# Name: sepalwidthcm, Length: 150, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             NaN           NaN            NaN           NaN          NaN
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             NaN           NaN            NaN           NaN          NaN
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.where(admit_mask).dropna().head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa

# %%
df[df['sepalwidthcm'] > 3.1].head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa

# %%
df["species"].head()
# Out:
# Id
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# Name: species, dtype: object

# %%
df[["petalwidthcm","species"]].head()
# Out:
#     petalwidthcm      species
# Id
# 1            0.2  Iris-setosa
# 2            0.2  Iris-setosa
# 3            0.2  Iris-setosa
# 4            0.2  Iris-setosa
# 5            0.2  Iris-setosa

# %%
df[df["petalwidthcm"]>0.2].head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 16            5.7           4.4            1.5           0.4  Iris-setosa
# 17            5.4           3.9            1.3           0.4  Iris-setosa
# 18            5.1           3.5            1.4           0.3  Iris-setosa

# %%
(df['sepalwidthcm'] > 3.1) & (df['sepalwidthcm'] < 3.5)
# Out:
# Id
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
#        ...
# 146    False
# 147    False
# 148    False
# 149     True
# 150    False
# Name: sepalwidthcm, Length: 150, dtype: bool

# %%
df['sepalwidthcm'].gt(3.1) & df['sepalwidthcm'].lt(3.5)
# Out:
# Id
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
#        ...
# 146    False
# 147    False
# 148    False
# 149     True
# 150    False
# Name: sepalwidthcm, Length: 150, dtype: bool

# %%
df['sepalwidthcm'].gt(3.1).lt(3.5)
# Out:
# Id
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
#        ...
# 146    True
# 147    True
# 148    True
# 149    True
# 150    True
# Name: sepalwidthcm, Length: 150, dtype: bool

# %% [markdown]
# # Data Frame and Indexing

# %%
df['Serial Number'] = df.index
df = df.set_index('species')
df.head()
# Out:
#              sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# species
# Iris-setosa            5.1           3.5            1.4           0.2
# Iris-setosa            4.9           3.0            1.4           0.2
# Iris-setosa            4.7           3.2            1.3           0.2
# Iris-setosa            4.6           3.1            1.5           0.2
# Iris-setosa            5.0           3.6            1.4           0.2
#
#              Serial Number
# species
# Iris-setosa              1
# Iris-setosa              2
# Iris-setosa              3
# Iris-setosa              4
# Iris-setosa              5

# %%
df = df.reset_index()
df.head()
# Out:
#        species  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0  Iris-setosa            5.1           3.5            1.4           0.2
# 1  Iris-setosa            4.9           3.0            1.4           0.2
# 2  Iris-setosa            4.7           3.2            1.3           0.2
# 3  Iris-setosa            4.6           3.1            1.5           0.2
# 4  Iris-setosa            5.0           3.6            1.4           0.2
#
#    Serial Number
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
df['sepalwidthcm'].unique()
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 2.9, 3.7, 4. , 4.4, 3.8, 3.3,
#        4.1, 4.2, 2.3, 2.8, 2.4, 2.7, 2. , 2.2, 2.5, 2.6])

# %%
df=df[df['sepalwidthcm'] == 3.5]
df.head()
# Out:
#         species  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0   Iris-setosa            5.1           3.5            1.4           0.2
# 17  Iris-setosa            5.1           3.5            1.4           0.3
# 27  Iris-setosa            5.2           3.5            1.5           0.2
# 36  Iris-setosa            5.5           3.5            1.3           0.2
# 40  Iris-setosa            5.0           3.5            1.3           0.3
#
#     Serial Number
# 0               1
# 17             18
# 27             28
# 36             37
# 40             41

# %%
columns_to_keep = ['sepalwidthcm','petalwidthcm', 'species']
df = df[columns_to_keep]
df.head()
# Out:
#     sepalwidthcm  petalwidthcm      species
# 0            3.5           0.2  Iris-setosa
# 17           3.5           0.3  Iris-setosa
# 27           3.5           0.2  Iris-setosa
# 36           3.5           0.2  Iris-setosa
# 40           3.5           0.3  Iris-setosa

# %%
df = df.set_index(['sepalwidthcm','petalwidthcm'])
df.head()
# Out:
#                                species
# sepalwidthcm petalwidthcm
# 3.5          0.2           Iris-setosa
#              0.3           Iris-setosa
#              0.2           Iris-setosa
#              0.2           Iris-setosa
#              0.3           Iris-setosa

# %%
df = pd.read_csv('Iris.csv', index_col=0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Missing at Random or Missing completely

# %%
df.head(10)
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
mask=df.isnull() #for identification of null values
mask.head(10)
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  species
# Id
# 1           False         False          False         False    False
# 2           False         False          False         False    False
# 3           False         False          False         False    False
# 4           False         False          False         False    False
# 5           False         False          False         False    False
# 6           False         False          False         False    False
# 7           False         False          False         False    False
# 8           False         False          False         False    False
# 9           False         False          False         False    False
# 10          False         False          False         False    False

# %%
# for replacing Nan with 0 we use
df.fillna(0, inplace=True)
df.head(10)
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# for dropping Nan values we use
df.dropna().head(10)
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df = df.set_index('sepallengthcm')
df = df.sort_index()
df.head(10)
# Out:
#                petallengthcm  petalwidthcm      species
# sepallengthcm
# 4.3                      1.1           0.1  Iris-setosa
# 4.4                      1.3           0.2  Iris-setosa
# 4.4                      1.4           0.2  Iris-setosa
# 4.4                      1.3           0.2  Iris-setosa
# 4.5                      1.3           0.3  Iris-setosa
# 4.6                      1.4           0.2  Iris-setosa
# 4.6                      1.5           0.2  Iris-setosa
# 4.6                      1.0           0.2  Iris-setosa
# 4.6                      1.4           0.3  Iris-setosa
# 4.7                      1.3           0.2  Iris-setosa

# %%
df = df.reset_index()
df = df.set_index(['sepallengthcm','petallengthcm'])
df
# Out:
#                              petalwidthcm         species
# sepallengthcm petallengthcm
# 4.3           1.1                     0.1     Iris-setosa
# 4.4           1.3                     0.2     Iris-setosa
#               1.4                     0.2     Iris-setosa
#               1.3                     0.2     Iris-setosa
# 4.5           1.3                     0.3     Iris-setosa
# ...                                   ...             ...
# 7.7           6.9                     2.3  Iris-virginica
#               6.7                     2.2  Iris-virginica
#               6.1                     2.3  Iris-virginica
#               6.7                     2.0  Iris-virginica
# 7.9           6.4                     2.0  Iris-virginica
#
# [150 rows x 2 columns]

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                              petalwidthcm      species
# sepallengthcm petallengthcm
# 4.3           1.1                     0.1  Iris-setosa
# 4.4           1.3                     0.2  Iris-setosa
#               1.4                     0.2  Iris-setosa
#               1.3                     0.2  Iris-setosa
# 4.5           1.3                     0.3  Iris-setosa

# %%
df = pd.DataFrame({'A': [1, 1, 2, 3, 4],
                  'B': [3, 6, 3, 8, 9],
                  'C': ['a', 'b', 'c', 'd', 'e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1, 100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace([1, 3], [100, 300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
#Using REgax
df.replace(to_replace=".*3.5$", value="sepalwidthcm", regex=True)
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df = pd.read_csv('Iris.csv', index_col=0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
import re
df.replace(to_replace=".*3.5$", value="sepalwidthcm", regex=True)
# Out:
#      sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm         species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Manipulating Dataset

# %%
df["First"]=df['sepalwidthcm']
df["First"]=df["First"].replace("[ ].*", "", regex=True)
df.head()
# Out:
#     sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm      species  \
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
#
#     First
# Id
# 1     3.5
# 2     3.0
# 3     3.2
# 4     3.1
# 5     3.6

# %%
del(df["First"])
def splitname(row):
    row['First']=row['sepalwidthcm'].split(" ")[0]
    row['Last']=row['sepalwidthcm'].split(" ")[-1]
    return now
df=df.apply(splitname,axis='columns')
df.head()
del(df['First'])
del(df['Last'])
pattern="(^[\w]*)(?:.* )([\w]*$)"
df["sepalwidthcm"].str.extract(pattern).head()
0 and 1
pattern="(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"
names=df["sepalwidthcm"].str.extract(pattern).head()
names
#withfirst and last name
df["First"]=names["First"]
df["last"]=names["last"]
df.head()

df["Born"]=df["Born"].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")
df["Born"].head()
df["Born"]=pd.to_datetime(df["Born"])
df["Born"].head()
